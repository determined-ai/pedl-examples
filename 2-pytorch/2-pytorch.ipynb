# %% [markdown]
# # CIFAR10 Pytorch

# %%
import torch
from keras.datasets import cifar10

from util import format_predictions, plot_images

# %matplotlib inline

# %%
# !pedl e create cifar10_cnn_pytorch/const.yaml cifar10_cnn_pytorch/

# %% [markdown]
# ![Experiment Start](images/pytorch-experiment-start.png "Experiment Start")

# %% [markdown]
# ![Experiment Complete](images/pytorch-experiment-complete.png "Experiment Complete")

# %%
# !pedl checkpoint download-s3 <trail-id> <step-id> ./model/

# %%
# !ls model/
# Out:
# model.pytorch     optimizer.pytorch

# %%
model = torch.load('model/model.pytorch')
model
# Out:
# OrderedDict([('0.weight', tensor([[[[-1.3672e-01,  1.7096e-01,  1.6901e-01],
#                         [-1.7656e-01,  1.2606e-01,  1.6398e-01],
#                         [ 3.1267e-02, -8.6991e-02, -1.7949e-01]],
#
#                        [[ 9.0403e-02,  6.0576e-02,  1.9103e-01],
#                         [-1.3231e-01, -1.6159e-02, -7.3839e-02],
#                         [ 1.8121e-01,  7.3067e-02,  9.6874e-02]],
#
#                        [[-1.0058e-01,  9.3915e-02,  3.7740e-02],
#                         [-6.0073e-02,  5.6558e-02,  1.3981e-01],
#                         [ 6.1319e-02, -5.8609e-03,  6.6322e-02]]],
#
#
#                       [[[ 4.6974e-02,  1.2956e-01, -7.6397e-02],
#                         [-2.7733e-02, -7.5419e-02,  1.1928e-01],
#                         [ 7.0895e-02,  1.1353e-02, -1.0581e-01]],
#
#                        [[ 1.2966e-01,  1.7708e-01, -1.6977e-01],
#                         [-1.3615e-01, -1.2900e-01,  1.4790e-01],
# ...
