# %% [markdown]
# # CIFAR10 Tensorflow Keras

# %%
import tensorflow as tf
import keras
from keras.datasets import cifar10

from util import format_predictions, plot_images

# %matplotlib inline

# %%
# !pedl e create cifar10_cnn_tf_keras/const.yaml cifar10_cnn_tf_keras/

# %% [markdown]
# ![Experiment Start](images/experiment-start.png "Experiment Start")

# %% [markdown]
# ![Experiment Complete](images/experiment-complete.png "Experiment Complete")

# %%
# !pedl checkpoint download-s3 <trial-id> <step-id> ./model/

# %%
# !ls model/
# Out:
# pedl-keras-model

# %%
model = tf.keras.models.load_model(
    './model/pedl-keras-model'
)
model

# %%
num_classes = 10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

categorical_y_test = y_test

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
plot_images(x_test[:9], categorical_y_test[:9])

# %%
predictions = model.predict(x_test[:9])
predictions = format_predictions(predictions)
predictions
# Out:
# array([5, 1, 1, 1, 7, 9, 1, 0, 5])

# %%
plot_images(x_test[:9], categorical_y_test[:9], predictions)
